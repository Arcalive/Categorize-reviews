# %% [markdown]
# ## Colab KorBERT Intention Classification WEB 구동

# %% [markdown]
# 시작전에 server.py, run_intent_classify.py, settings.py requirements_colab.txt, templates, static 폴더와 파일을 각자의 드라이브에 업로드
#
# (bert finetuning에 사용했던 폴더들이 있는 경로에 업로드)

# %%
# 드라이브 마운트
import os
from google.colab import drive
drive.mount("/content/drive")

path = '*******************************************'
os.chdir(path)

# %%
# !pip uninstall tensorflow -y

# %%
# !pip install -r requirements_colab.txt

# %%
# 실행
# !python server.py
